# %% [markdown]
# # Likes Report

# %% [markdown]
# ### McKenna Gammon
# ### September 21, 2021

# %% [markdown]
# #### Who collected this data?

# %% [markdown]
# The data used for this assignment was collected by Instagram. This data was most likely collected through technology Instagram uses to track each users activities; liking, commenting, posting, messaging, sharing, etc.

# %% [markdown]
# #### Why was this data collected?

# %% [markdown]
# This data was collected most likely for Instagram to get turn this collection of data into information in order to know more about their users and use that information in different ways to their benefit. For example, targeting ads, suggesting other alike users to follow, etc. The Ted Talk we watched detailed how Target observed and drew conclusions from the data they collected to determine that a woman was pregnant. So, from these data collections, the conclusions drawn can allow sources like Instagram and companies like Target to make insightful and data-driven conclusions to inform their actions towards the users/consumers.

# %% [markdown]
# #### In what ways may this data be reliable?

# %% [markdown]
# This data could be reliable in the sense that every piece of data is extracted from an action I did take on Instagram. So, it is based off of real actions I took that Instagram collected. Therefore, the data points represent real events that ocurred which could be seen as a valid logic for determining the data as reliable.

# %% [markdown]
# #### In what ways may this data be unreliable?

# %% [markdown]
# This data could be unreliable in a few ways. First, when I was analyzing the interests and likes files collected from my profile, I saw things listed under 'interests' because of profiles or other things I've looked at only once in relation to that interest subject on Instagram. So, I don't think that makes that subject an interest of mine. Also, I've had Instagram for a long time and my interests have changed a lot from when I was in middle school. So, a lot of these interests don't align with what I'm interested in.

# %%
import pandas as pd
import json
import matplotlib as plt

# %%
with open(r"/Users/mckennagammon/Downloads/mckennagammon_20210907/likes/liked_posts.json") as p:
    dat = json.load(p)

# %%
dat
# Out:
# {'likes_media_likes': [{'title': 'maren418',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/aoPCPqjB1g/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371421173}]},
#   {'title': 'samsilber130',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/aoP9e0AdBMFffuF2FPpZIbGopEEAiV47nAXbg0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371421109}]},
#   {'title': 'livinlikelindsey',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/aoT0duNczZ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371421007}]},
#   {'title': 'anastasiabeverlyhills',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/aoXJUPh6M6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371420817}]},
#   {'title': 'iancrazyman',
#    'media_list_data': [],
# ...

# %%
dat.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
dat['likes_media_likes']
# Out:
# [{'title': 'maren418',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/aoPCPqjB1g/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371421173}]},
#  {'title': 'samsilber130',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/aoP9e0AdBMFffuF2FPpZIbGopEEAiV47nAXbg0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371421109}]},
#  {'title': 'livinlikelindsey',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/aoT0duNczZ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371421007}]},
#  {'title': 'anastasiabeverlyhills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/aoXJUPh6M6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371420817}]},
#  {'title': 'iancrazyman',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/aoXPMOTT4f/',
#     'value': 'ð\x9f\x91\x8d',
# ...

# %%
type(dat['likes_media_likes'])
# Out:
# list

# %%
len(dat['likes_media_likes'])
# Out:
# 50435

# %%
liked_posts = pd.DataFrame(dat['likes_media_likes'])

# %%
liked_posts
# Out:
#                         title media_list_data  \
# 0                    maren418              []
# 1                samsilber130              []
# 2            livinlikelindsey              []
# 3       anastasiabeverlyhills              []
# 4                 iancrazyman              []
# ...                       ...             ...
# 50430  moonlightenergyhealing              []
# 50431        shopsteviehender              []
# 50432                 threads              []
# 50433               emijayinc              []
# 50434           shoprocknrags              []
#
#                                         string_list_data
# 0      [{'href': 'https://www.instagram.com/p/aoPCPqj...
# 1      [{'href': 'https://www.instagram.com/p/aoP9e0A...
# 2      [{'href': 'https://www.instagram.com/p/aoT0duN...
# 3      [{'href': 'https://www.instagram.com/p/aoXJUPh...
# 4      [{'href': 'https://www.instagram.com/p/aoXPMOT...
# ...                                                  ...
# ...

# %%
liked_posts.keys()
# Out:
# Index(['title', 'media_list_data', 'string_list_data'], dtype='object')

# %%
Lp = dat['likes_media_likes'][0]

# %%
Lp
# Out:
# {'title': 'maren418',
#  'media_list_data': [],
#  'string_list_data': [{'href': 'https://www.instagram.com/p/aoPCPqjB1g/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371421173}]}

# %%
type(Lp)
# Out:
# dict

# %%
listlp = pd.DataFrame(dat['likes_media_likes'])

# %%
listlp
# Out:
#                         title media_list_data  \
# 0                    maren418              []
# 1                samsilber130              []
# 2            livinlikelindsey              []
# 3       anastasiabeverlyhills              []
# 4                 iancrazyman              []
# ...                       ...             ...
# 50430  moonlightenergyhealing              []
# 50431        shopsteviehender              []
# 50432                 threads              []
# 50433               emijayinc              []
# 50434           shoprocknrags              []
#
#                                         string_list_data
# 0      [{'href': 'https://www.instagram.com/p/aoPCPqj...
# 1      [{'href': 'https://www.instagram.com/p/aoP9e0A...
# 2      [{'href': 'https://www.instagram.com/p/aoT0duN...
# 3      [{'href': 'https://www.instagram.com/p/aoXJUPh...
# 4      [{'href': 'https://www.instagram.com/p/aoXPMOT...
# ...                                                  ...
# ...

# %%
posts_liked = pd.DataFrame(listlp)

# %%
posts_liked
# Out:
#                         title media_list_data  \
# 0                    maren418              []
# 1                samsilber130              []
# 2            livinlikelindsey              []
# 3       anastasiabeverlyhills              []
# 4                 iancrazyman              []
# ...                       ...             ...
# 50430  moonlightenergyhealing              []
# 50431        shopsteviehender              []
# 50432                 threads              []
# 50433               emijayinc              []
# 50434           shoprocknrags              []
#
#                                         string_list_data
# 0      [{'href': 'https://www.instagram.com/p/aoPCPqj...
# 1      [{'href': 'https://www.instagram.com/p/aoP9e0A...
# 2      [{'href': 'https://www.instagram.com/p/aoT0duN...
# 3      [{'href': 'https://www.instagram.com/p/aoXJUPh...
# 4      [{'href': 'https://www.instagram.com/p/aoXPMOT...
# ...                                                  ...
# ...

# %%
Pl = [x['string_list_data'][0] for x in dat['likes_media_likes']]

# %%
Pl
# Out:
# [{'href': 'https://www.instagram.com/p/aoPCPqjB1g/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371421173},
#  {'href': 'https://www.instagram.com/p/aoP9e0AdBMFffuF2FPpZIbGopEEAiV47nAXbg0/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371421109},
#  {'href': 'https://www.instagram.com/p/aoT0duNczZ/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371421007},
#  {'href': 'https://www.instagram.com/p/aoXJUPh6M6/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371420817},
#  {'href': 'https://www.instagram.com/p/aoXPMOTT4f/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371420807},
#  {'href': 'https://www.instagram.com/p/aobkMaHP87/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371420663},
#  {'href': 'https://www.instagram.com/p/aobtLDtc0K/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371420658},
#  {'href': 'https://www.instagram.com/p/aogI5Ch6Pm/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371420517},
# ...

# %%
string_list = pd.DataFrame(Pl)

# %%
string_list
# Out:
#                                                     href value   timestamp
# 0                https://www.instagram.com/p/aoPCPqjB1g/  ð  1371421173
# 1      https://www.instagram.com/p/aoP9e0AdBMFffuF2FP...  ð  1371421109
# 2                https://www.instagram.com/p/aoT0duNczZ/  ð  1371421007
# 3                https://www.instagram.com/p/aoXJUPh6M6/  ð  1371420817
# 4                https://www.instagram.com/p/aoXPMOTT4f/  ð  1371420807
# ...                                                  ...   ...         ...
# 50430           https://www.instagram.com/p/CRpl9pnnZw0/  ð  1627081173
# 50431           https://www.instagram.com/p/CRrsv5EBop4/  ð  1627081170
# 50432        https://www.instagram.com/reel/CRrddi-jILi/  ð  1627081129
# 50433           https://www.instagram.com/p/CRrOxWRtPpp/  ð  1627081123
# 50434           https://www.instagram.com/p/CRr2DlMMw_l/  ð  1627081112
#
# [50435 rows x 3 columns]

# %%
string_list.groupby('timestamp').count().sort_values('timestamp', ascending = False)
# Out:
#             href  value
# timestamp
# 1630961011     1      1
# 1630961005     1      1
# 1630961001     1      1
# 1630940967     1      1
# 1630940958     1      1
# ...          ...    ...
# 1344781095     1      1
# 1344605012     1      1
# 1344568912     1      1
# 1344461530     1      1
# 1344461463     1      1
#
# [50304 rows x 2 columns]

# %%
string_list.groupby('timestamp').count().sort_values('timestamp', ascending = False).plot(y='value')
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# #### Source and structure of the data
# The source of the data used in this assignment is Instagram. The structure of the data came in the form of JSON files that were categorized in folders created by Instagram based on the data that they collect. Throughout the assignment we used list comprehension and other techniques to restructure the data into a data frame to make the data easier for a human to visually analyze.

# %% [markdown]
# #### Statistical and theoretical hypothesis
# ***Statistical***
# There is no difference between the number of likes in the range of timestamp from 1630961011 to 1630940958 and the number of likes in the range of timestamps from 1344781095 to 1344461463. (The five oldest likes according to timestamp and the five most recent likes, before I downloaded my Instagram data, according to the data frame showing numerically sorted timestamps).
#
# ***Theoretical***
# I have many more recent likes than I do older likes according to the timestamps of posts liked data Instagram has collected from my account because I use Instagram a lot more than I used to.
#
# #### Instead of a data file provided by Instagram, what would be the ideal data to use to test your hypothesis?
# The hypothesis could be changed to focusing on a certain group of users or instagram as a whole, instead of just myself. Then, the ideal data, to test the hypothesis that there are more posts liked in recent years than in the earlier years of Instagram, would be a collection of statistics or Instagram data files put together to correctly make a conclusion.

# %% [markdown]
# #### Data-driven conclusion
# From the graph and raw data it can be seen that there are more data points (posts liked in this case) collected with timestamps of higher values and less data points (posts liked) with lower timestamp values.

# %% [markdown]
# #### Limitations, alternative approaches, and potential next steps
# Some potential next steps could include actually testing the hypothesis. Looking at the range of numbers and how spread out they start (from the older/earlier likes) and looking at the range of numbers as well as how spread out the timestamps data points are for that range. Then, comparing these two outputs. The limitations on this is it seems very complicated to actually complete, although it could definitely be done.
