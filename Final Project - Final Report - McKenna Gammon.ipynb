# %% [markdown]
# ### Final Project: Final Report
# ### McKenna Gammon

# %% [markdown]
# I found my original dataset early on in the beginning stages of this project. The data set is a file in CSV format which contains data for movies that are available on the Netflix platform. The information or attributes included for each Netflix movie includes, but isn't limited to, the following: Actors, Genre, Awards Nominated For, Awards Received, Rotten Tomatoes Score, Hidden Gem Score, and Metacritic Score. Something that stuck out to me and interested me was the "Hidden Gem Score". The Hidden Gem Score is a score that the author of the dataset created. The author built a method of calculating if a Netflix movie is a "Hidden Gem" or not. What's meant by a Netflix movie being considered a "Hidden Gem" is if the count of the movie's reviews is low but, the movie's rating is high. The interest in this specific attribute kind of drove me to move forward with this project. Looking back now, I wish I had used a different data set or added data to compare the Hidden Gem Scores against how popular the Actor(s) and/or Actress(es) are thought to be.
#
# My analysis began with looking at the different ways I could narrow down the dataset because it was a large and overwhelming data set to look at. I attempted to centralize certain attributes available in the data set so that it didn't seem so overwhelming and my analysis would be more focused. I decided to compare Hidden Gem Scores, Metacritic Scores, and Rotten Tomatoes Scores. The question that drove this comparison was to see if there was a linear correlation between a movie's Hidden Gem Score and a movie's Metacritic Score or a movie's Hidden Gem Score and a movie's Rotten Tomatoes Score. I was able to create scatter plots for each of the two mentioned comparisons. However, pretty much all of the scores were set to very different scales speaking numerically. From the scatter plots comparing those different score attributes, it can be seen in the first scatter plot (comparing Netflix movie's Hidden Gem Scores to Netflix movie's Metacritic Scores) that, the scores both increase linearly together. The same visual comprehension is present in the second scatter plot (comparing Netflix movie's Hidden Gem Scores to Netflix movie's Rotten Tomatoes Scores). However, I do understand that doesn't mean any final causation or correlation, especially because they are on such different scales.
#
# I didn't end up coming up with as finished or polished of a conclusion that I had hoped for, but it is a start to what could end up as a more fully fleshed outcome if more time and effort is put towards it in the future. Alternative approaches or steps that I would have taken if there was more time alotted to this project or ones I could accomplish in the future are: as previously mentioned, I would change the focus on this data set, add more data for a more complete or established analysis and final product. I would definitely even out the scales between the different scores being compared (Hidden Gem Score vs. Metacritic Score and Hidden Gem Score vs. Rotten Tomatoes Score) for a more clean and more easily understandable visual result.
#
# - I deleted a lot of code cells from my analysis and other tasks for clearness and conciseness of final representation.

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats

# %%
ls
# Out:
# Aug31_inclass_practice.ipynb
# Equal_Audio_Features.csv
# Equal_Track_Data.csv
# Final Project - Data in Hand.ipynb
# Final Project - Final Report - McKenna Gammon.ipynb
# Final Project Analysis Plan - McKenna Gammon.ipynb
# Likes Report.ipynb
# Montero
# Montero_Audio_Features.csv
# Montero_Track_Data.csv
# Nov-2-in-class-(statistical tests).ipynb
# Nov-4-in-class-bivariate.ipynb
# Oct-19-In-Class.ipynb
# Oct-26-in-class.ipynb
# October 5 - Twitter API.ipynb
# October-21-in-class (Indeed).ipynb
# October-7-in-class.ipynb
# Olympics_Postponed_Twitter_Unique.csv
# Preliminary Draft - Final Project - McKenna Gammon.ipynb
# Sept 7 - In-Class 2.ipynb
# Sept. 7 - In-Class.ipynb
# Sept.30_in_class.ipynb
# Spotify_API_Knight.ipynb
# Twitter Text Report.ipynb
# Twitter-keys.txt
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# bls_data.csv
# chinook.db
# netflix-rotten-tomatoes-metacritic-imdb.csv
# sept-28.ipynb

# %%
netflix_data = pd.read_csv('netflix-rotten-tomatoes-metacritic-imdb.csv', encoding = 'utf-8')

# %%
netflix_data
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix_data.keys()
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
countries_list = netflix_data['Country Availability'].astype('category')

# %%
countries_list
# Out:
# 0                                                 Thailand
# 1                                                   Canada
# 2                                                   Canada
# 3                                      Belgium,Netherlands
# 4        Lithuania,Poland,France,Iceland,Italy,Spain,Gr...
#                                ...
# 15475    South Korea,Argentina,United Kingdom,Australia...
# 15476    Russia,Hong Kong,Hungary,Australia,South Korea...
# 15477    Belgium,Switzerland,United States,Germany,Unit...
# 15478    Belgium,Switzerland,Germany,Argentina,United K...
# 15479    Belgium,Switzerland,Germany,United Kingdom,Fra...
# Name: Country Availability, Length: 15480, dtype: category
# ...

# %%
rotten_tomatoes_scores = netflix_data['Rotten Tomatoes Score']

# %%
rotten_tomatoes_scores
# Out:
# 0        98.0
# 1        79.0
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 15475     NaN
# 15476     NaN
# 15477     NaN
# 15478     NaN
# 15479     NaN
# Name: Rotten Tomatoes Score, Length: 15480, dtype: float64

# %%
hidden_gem_scores = netflix_data['Hidden Gem Score']

# %%
hidden_gem_scores
# Out:
# 0        4.3
# 1        7.0
# 2        6.4
# 3        7.7
# 4        8.1
#         ...
# 15475    NaN
# 15476    NaN
# 15477    8.4
# 15478    8.2
# 15479    8.1
# Name: Hidden Gem Score, Length: 15480, dtype: float64

# %%
meta_critic_scores = netflix_data['Metacritic Score']

# %%
meta_critic_scores
# Out:
# 0        82.0
# 1        69.0
# 2        46.0
# 3         NaN
# 4         NaN
#          ...
# 15475     NaN
# 15476     NaN
# 15477     NaN
# 15478     NaN
# 15479     NaN
# Name: Metacritic Score, Length: 15480, dtype: float64

# %%
import numpy as np

# %%
test = np.random.randn(10)
test * .1
# Out:
# array([ 0.06886849,  0.06558074, -0.02852397, -0.09897679, -0.10360781,
#        -0.1308676 ,  0.05001972, -0.08749014,  0.02061648,  0.14633247])

# %%
fig1, ax1 = plt.subplots(1, 1, figsize = (10, 10))
ax1.scatter(meta_critic_scores, hidden_gem_scores)
ax1.set_title("Netflix Movies: MetaCritic Scores vs. Hidden Gem Scores")
ax1.set_ylim(0,30)
ax1.set_xlim(0,100)
plt.show()

# %%
fig2, ax2 = plt.subplots(1, 1, figsize = (10, 10))
ax2.scatter(rotton_tomatoes_scores, hidden_gem_scores)
ax2.set_title("Netflix Movies: Rotton Tomatoes Scores vs. Hidden Gem Scores")
ax2.set_ylim(0,30)
ax2.set_xlim(0,100)
plt.show()
